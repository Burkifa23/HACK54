# %%
import pandas as pd
from IPython.display import display

df = pd.read_csv("data.csv")
display(df)
# Out:
#             region               city  month  year  rainfall(mm)  \
# 0    Greater Accra              Accra      8  2014         210.5
# 1    Greater Accra              Accra      9  2014         235.2
# 2    Greater Accra              Accra     10  2014         180.1
# 3    Greater Accra              Accra      7  2014         195.3
# 4          Central         Cape Coast      8  2014         175.4
# ..             ...                ...    ...   ...           ...
# 205     Upper West                 Wa      1  2017           8.9
# 206    Brong Ahafo            Sunyani      2  2017          38.1
# 207        Western   Sekondi-Takoradi      3  2017          50.0
# 208          Volta                 Ho      3  2017          62.1
# 209        Central  Awutu-Efutu-Senya      4  2017          75.3
#
#      temperature(celsius)  sanitation_Index  water_quality_index  \
# 0                    26.2              22.5                 55.1
# ...
